# %% [markdown]
# <a href="https://colab.research.google.com/github/Lekshmi02K/CCHVAE_repo/blob/main/Copy_of_cchvae%20runs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/CCHVAE
# Out:
# /content/CCHVAE

# %%
# !pip install torch torchvision torchaudio transformers datasets scikit-learn pandas numpy nltk sentencepiece accelerate

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !ls
# Out:
# baseline_model.py  test_preprocessed.csv   val_preprocessed.csv
# preprocess.py	   train_baseline.py
# README.md	   train_preprocessed.csv

# %%
# %cd /content/CCHVAE
# !python preprocess.py
# Out:
# /content/CCHVAE
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Columns detected: Index(['Unnamed: 0', 'user_id', 'prod_id', 'rating', 'label', 'date', 'text',
#        'tag'],
#       dtype='object')
# Sample rows:
#     Unnamed: 0  user_id  ...                                               text   tag
# 0           0     5044  ...  Drinks were bad, the hot chocolate was watered...  fake
# 1           1     5045  ...  This was the worst experience I've ever had a ...  fake
# 2           2     5046  ...  This is located on the site of the old Spruce ...  fake
# 3           3     5047  ...  I enjoyed coffee and breakfast twice at Toast ...  fake
# 4           4     5048  ...  I love Toast! The food choices are fantastic -...  fake
#
# [5 rows x 8 columns]
# Label distribution:
#  label
# 0    528019
# 1     80439
# Name: count, dtype: int64
# ...

# %%
import pandas as pd

RAW_PATH = "/content/CCHVAE/yelpzip.csv"

# Try reading with comma
df_comma = pd.read_csv(RAW_PATH, sep=",", engine="python", on_bad_lines="skip")
print("Comma rows:", len(df_comma))

# Try reading with tab
df_tab = pd.read_csv(RAW_PATH, sep="\t", engine="python", on_bad_lines="skip")
print("Tab rows:", len(df_tab))
# Out:
# Comma rows: 608458
# Tab rows: 608458

# %%
# %cd /content/CCHVAE
# !python train_baseline.py
# Out:
# /content/CCHVAE
# Train samples: 425920
# Val samples: 91269
# Using device: cuda
# ...
# Loading weights: 100% 197/197 [00:00<00:00, 2201.72it/s]
# [transformers] RobertaModel LOAD REPORT from: roberta-base
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# pooler.dense.weight       | MISSING    |
# pooler.dense.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Loading weights: 100% 148/148 [00:00<00:00, 22643.79it/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Lekshmi02K/CCHVAE_repo.git
# %cd CCHVAE_repo
# !cp /content/drive/MyDrive/CCHVAE/hamvae_epoch2.pt .
# !git add hamvae_epoch2.pt
# !git commit -m "Add trained HAM-VAE model checkpoint"
# !git push
# Out:
# Cloning into 'CCHVAE_repo'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 326.72 KiB | 1.39 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/CCHVAE_repo
# cp: cannot stat '/content/drive/MyDrive/CCHVAE/hamvae_epoch2.pt': No such file or directory
# fatal: pathspec 'hamvae_epoch2.pt' did not match any files
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@bd27497dfc9e.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import pandas as pd

RAW_PATH = "/content/CCHVAE_repo/yelpzip.csv"

# Try reading with comma
df_comma = pd.read_csv(RAW_PATH, sep=",", engine="python", on_bad_lines="skip")
print("Comma rows:", len(df_comma))

# Try reading with tab
df_tab = pd.read_csv(RAW_PATH, sep="\t", engine="python", on_bad_lines="skip")
print("Tab rows:", len(df_tab))
# Out:
# Comma rows: 608458
# Tab rows: 608458

# %%
# !python preprocess.py
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Columns detected: Index(['Unnamed: 0', 'user_id', 'prod_id', 'rating', 'label', 'date', 'text',
#        'tag'],
#       dtype='object')
# Sample rows:
#     Unnamed: 0  user_id  ...                                               text   tag
# 0           0     5044  ...  Drinks were bad, the hot chocolate was watered...  fake
# 1           1     5045  ...  This was the worst experience I've ever had a ...  fake
# 2           2     5046  ...  This is located on the site of the old Spruce ...  fake
# 3           3     5047  ...  I enjoyed coffee and breakfast twice at Toast ...  fake
# 4           4     5048  ...  I love Toast! The food choices are fantastic -...  fake
#
# [5 rows x 8 columns]
# Label distribution:
#  label
# 0    528019
# ...

# %%
# !python train_baseline.py
# Out:
# Train samples: 425920
# Val samples: 91269
# ...
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 115kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 4.65MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 17.5MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 5.71MB/s]
# Using device: cuda
# config.json: 100% 481/481 [00:00<00:00, 2.53MB/s]
#
# model.safetensors: downloading bytes:  53% 266M/499M [00:02<00:01, 132MB/s, 23.3MB/s  ]
# model.safetensors: downloading bytes:  63% 313M/499M [00:02<00:01, 135MB/s, 26.4MB/s  ]
# model.safetensors: downloading bytes:  67% 335M/499M [00:02<00:01, 128MB/s, 28.1MB/s  ]
# model.safetensors: downloading bytes: 100% 335M/335M [00:02<00:00, 118MB/s, 29.1MB/s  ]
# model.safetensors: reconstructing file: 100% 499M/499M [00:02<00:00, 175MB/s, 45.3MB/s  ]
# Loading weights: 100% 197/197 [00:00<00:00, 19617.70it/s]
# [transformers] RobertaModel LOAD REPORT from: roberta-base
# Key                       | Status     |
# ...
